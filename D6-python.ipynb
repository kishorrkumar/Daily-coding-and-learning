# %%
students = { "Arun": 85, "priya":92, "john" : 78}
name = input("enter student  name: ")

marks  = students.get(name)
print("Marks: ", marks)
# Out:
# enter student  name:  priya
# Marks:  92

# %%
marks = {"Maths": 85,"Science": 90,"English": 88}

total = sum(marks.values())

print("Total Marks:", total)
# Out:
# Total Marks: 263

# %%
marks = {"Maths": 85,"Science": 90,"English": 88}

marks.values()
